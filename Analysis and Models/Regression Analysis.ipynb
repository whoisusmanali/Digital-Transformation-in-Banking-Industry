# %% [markdown]
# # Regression Analysis

# %% [markdown]
# ### 1. Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Loading the data

# %%
unemployment = pd.read_csv('/Users/usmanali/Uwindsor/Forth/Project/Data Collection/Historic Data of Economical Indicators/Unemployement Rate.csv')
stocks_data = pd.read_csv('/Users/usmanali/Uwindsor/Forth/Project/Data Collection/Historic Data of Economical Indicators/Stock Exchange Index.csv')
RD_spending_data = pd.read_csv('/Users/usmanali/Uwindsor/Forth/Project/Data Collection/Historic Data of Economical Indicators/R&D Spending in Canada.csv')
productivity_data = pd.read_csv('/Users/usmanali/Uwindsor/Forth/Project/Data Collection/Historic Data of Economical Indicators/Labour Productivity rate.csv')
interest_rate = pd.read_csv('/Users/usmanali/Uwindsor/Forth/Project/Data Collection/Historic Data of Economical Indicators/interest_rate.csv')
gdp = pd.read_csv('/Users/usmanali/Uwindsor/Forth/Project/Data Collection/Historic Data of Economical Indicators/GDP.csv')
cpi = pd.read_csv('/Users/usmanali/Uwindsor/Forth/Project/Data Collection/Historic Data of Economical Indicators/CPI.csv')
consumer_confidence = pd.read_csv('/Users/usmanali/Uwindsor/Forth/Project/Data Collection/Historic Data of Economical Indicators/Consumer Confidence Index.csv')

# %%
dependent = pd.read_csv('/Users/usmanali/Uwindsor/Forth/Project/Data Collection/Historic Data of Economical Indicators/Dependent Variables.csv')

# %% [markdown]
# ### 3. Data Cleaning

# %%
#Data Cleaning for Unemployement dataset
unemployment1 = unemployment
#Rename the columns
unemployment1.rename(columns = {'LRUNTTTTCAM156S' : 'unemployement_rate'},inplace=True)
unemployment1
#Get the correct Date
unemployment1['DATE'] = pd.to_datetime(unemployment1['DATE'])
unemployment1['Date'] = unemployment1['DATE'].dt.year

#Get the data for each year
unemployment1 = round(unemployment1.groupby(['Date'])['unemployement_rate'].mean(),2).reset_index()
unemployment1
# Out:
#     Date  unemployement_rate
# 0   1955                4.28
# 1   1956                3.30
# 2   1957                4.75
# 3   1958                7.13
# 4   1959                5.88
# ..   ...                 ...
# 65  2020                9.72
# 66  2021                7.48
# 67  2022                5.27
# 68  2023                5.41
# 69  2024                6.16
#
# [70 rows x 2 columns]

# %%
#Stock Data Cleaning
stocks_data1 = stocks_data
#Get the related columns
stocks_data1 = stocks_data1[['REF_DATE','VALUE']]
#Transform the data
stocks_data1['REF_DATE'] = pd.to_datetime(stocks_data1['REF_DATE'])
stocks_data1['Date'] = stocks_data1['REF_DATE'].dt.year
#Get the mean values
stocks_data1 = round(stocks_data1.groupby(['Date'])['VALUE'].mean(),2).reset_index()
stocks_data1 = stocks_data1.rename(columns= {'VALUE': "stock_value"})
stocks_data1
# Out:
# /var/folders/b2/pn6h715x3rz171jbp1s72snr0000gn/T/ipykernel_94529/1725370335.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stocks_data1['REF_DATE'] = pd.to_datetime(stocks_data1['REF_DATE'])
# /var/folders/b2/pn6h715x3rz171jbp1s72snr0000gn/T/ipykernel_94529/1725370335.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stocks_data1['Date'] = stocks_data1['REF_DATE'].dt.year
#     Date  stock_value
# 0   1956       570.94
# 1   1957       532.03
# 2   1958       495.15
# 3   1959       562.13
# 4   1960       513.79
# ..   ...          ...
# 63  2019      3750.48
# 64  2020      3683.18
# 65  2021      4537.20
# 66  2022      4639.44
# 67  2023      4649.78
#
# [68 rows x 2 columns]

# %%
#R&D data cleaning
RD_spending_data1 = RD_spending_data
#Data for canada
RD_spending_data1 = RD_spending_data1[RD_spending_data1['Country Name'] == 'Canada']

#Relevent columns
RD_spending_data1 = RD_spending_data1.drop(['Country Code','Indicator Name','Indicator Code'], axis= 1)
#Drop null values
RD_spending_data1.dropna(axis=1,inplace=True)
#Get the same columns for date
RD_spending_data1 = pd.melt(RD_spending_data1, id_vars=["Country Name"], var_name="Year", value_name="Value")
#Get the related columns
RD_spending_data1 = RD_spending_data1[['Year','Value']]
RD_spending_data1['Year'] = pd.to_datetime(RD_spending_data1['Year'])
RD_spending_data1['Year'] = RD_spending_data1['Year'].dt.year
RD_spending_data1 = RD_spending_data1.rename(columns = {'Value' : 'R&D Spending'})
RD_spending_data1
# Out:
#     Year  R&D Spending
# 0   1996      1.606820
# 1   1997      1.613860
# 2   1998      1.710510
# 3   1999      1.749850
# 4   2000      1.858480
# 5   2001      2.021170
# 6   2002      1.971710
# 7   2003      1.967810
# 8   2004      1.997340
# 9   2005      1.971270
# 10  2006      1.943040
# 11  2007      1.903580
# 12  2008      1.855780
# 13  2009      1.917420
# 14  2010      1.825280
# 15  2011      1.787140
# 16  2012      1.772320
# 17  2013      1.705400
# 18  2014      1.714170
# 19  2015      1.693240
# 20  2016      1.729030
# 21  2017      1.687020
# 22  2018      1.737200
# 23  2019      1.755730
# 24  2020      1.894840
# 25  2021      1.697270
# 26  2022      1.551820
# 27  2023      1.740393

# %%
#Productivity data cleaning
productivity_data1 = productivity_data
#Get the specific data and columns by filtering
productivity_data1 = productivity_data1[productivity_data1['Industry'] == 'Finance and insurance, and holding companies [BS5B]'][['REF_DATE','VALUE']]

productivity_data1 = productivity_data1.reset_index()[['REF_DATE','VALUE']]
productivity_data1 = productivity_data1.rename(columns = {'VALUE' : 'labour_productivity'})
productivity_data1
# Out:
#     REF_DATE  labour_productivity
# 0       1997                 50.0
# 1       1998                 53.4
# 2       1999                 53.5
# 3       2000                 53.1
# 4       2001                 54.9
# 5       2002                 57.4
# 6       2003                 57.8
# 7       2004                 58.0
# 8       2005                 58.1
# 9       2006                 61.0
# 10      2007                 62.5
# 11      2008                 60.6
# 12      2009                 62.4
# 13      2010                 61.8
# 14      2011                 62.7
# 15      2012                 63.9
# 16      2013                 65.8
# 17      2014                 66.6
# 18      2015                 70.6
# 19      2016                 72.1
# 20      2017                 79.2
# 21      2018                 81.9
# 22      2019                 82.5
# 23      2020                 88.6
# 24      2021                 86.5
# 25      2022                 90.8
# 26      2023                 87.3

# %%
#interest_rate
interest_rate
# Out:
#     Date  Interest
# 0   1995      5.56
# 1   1996      2.75
# 2   1997      4.35
# 3   1998      5.05
# 4   1999      4.75
# 5   2000      5.75
# 6   2001      2.25
# 7   2002      2.75
# 8   2003      2.75
# 9   2004      2.50
# 10  2005      3.00
# 11  2006      4.25
# 12  2007      4.25
# 13  2008      1.50
# 14  2009      0.25
# 15  2010      1.00
# 16  2011      1.00
# 17  2012      1.00
# 18  2013      1.00
# 19  2014      1.00
# 20  2015      0.50
# 21  2016      0.50
# 22  2017      1.00
# 23  2018      1.75
# 24  2019      1.75
# 25  2020      0.25
# 26  2021      0.25
# 27  2022      4.25
# 28  2023      5.00
# 29  2024      3.75

# %%
#GDP Data Cleaning
gdp1 = gdp
gdp1 = gdp1[gdp1['North American Industry Classification System (NAICS)'] == 'Finance and insurance [52]'][['REF_DATE','VALUE']]

#Covert into datetime
gdp1['REF_DATE'] = pd.to_datetime(gdp1['REF_DATE'])
gdp1['Date'] = gdp1['REF_DATE'].dt.year
gdp1 = gdp1.groupby(['Date'])['VALUE'].mean().reset_index()
gdp1 = gdp1.rename(columns = {'VALUE':'GDP'})
gdp1
# Out:
#     Date            GDP
# 0   1997   68998.083333
# 1   1998   70986.916667
# 2   1999   74535.833333
# 3   2000   78012.333333
# 4   2001   81636.000000
# 5   2002   83339.083333
# 6   2003   84585.750000
# 7   2004   89022.916667
# 8   2005   92295.833333
# 9   2006   99763.666667
# 10  2007  103770.000000
# 11  2008  102256.166667
# 12  2009  101237.083333
# 13  2010  103440.916667
# 14  2011  106951.000000
# 15  2012  108869.000000
# 16  2013  112858.166667
# 17  2014  116034.000000
# 18  2015  121689.083333
# 19  2016  125965.833333
# 20  2017  134991.000000
# 21  2018  138363.000000
# 22  2019  142002.000000
# 23  2020  146816.000000
# 24  2021  153897.000000
# 25  2022  156592.000000
# 26  2023  157319.500000
# 27  2024  158363.000000

# %%
#CPI Data Cleaning
cpi1 = cpi
cpi1 = cpi1[cpi1['Products and product groups'] == 'All-items'][['REF_DATE','VALUE']]
cpi1['Date'] = pd.to_datetime(cpi1['REF_DATE'], format = '%Y')
cpi1['Date'] = cpi1['Date'].dt.year
cpi1 = cpi1[['Date','VALUE']]
cpi1 = cpi1.rename(columns = {'VALUE' : 'CPI'})
cpi1
# Out:
#     Date    CPI
# 0   1950   12.5
# 1   1951   13.8
# 2   1952   14.2
# 3   1953   14.0
# 4   1954   14.1
# ..   ...    ...
# 69  2019  136.0
# 70  2020  137.0
# 71  2021  141.6
# 72  2022  151.2
# 73  2023  157.1
#
# [74 rows x 2 columns]

# %%
#Data cleaning for consumer confidence
consumer_confidence1 = consumer_confidence
consumer_confidence1['Category'] = pd.to_datetime(consumer_confidence1['Category'])
consumer_confidence1['Date'] = consumer_confidence1['Category'].dt.year
consumer_confidence1 = consumer_confidence1.groupby(['Date'])['OECD'].mean().reset_index()
consumer_confidence1 = consumer_confidence1.rename(columns= {'OECD' : 'consumer_confidence'})
consumer_confidence1
# Out:
#     Date  consumer_confidence
# 0   1974            98.605736
# 1   1975            99.461854
# 2   1976           100.941633
# 3   1977           101.138500
# 4   1978           101.454275
# 5   1979           100.212807
# 6   1980            98.980588
# 7   1981            98.753811
# 8   1982            98.827227
# 9   1983           100.291151
# 10  1984           100.953400
# 11  1985           101.006250
# 12  1986           101.359625
# 13  1987           101.300867
# 14  1988           101.677225
# 15  1989           101.407317
# 16  1990           100.606497
# 17  1991           100.176593
# 18  1992            99.591188
# 19  1993            99.338963
# 20  1994           100.715834
# 21  1995           100.728342
# 22  1996           100.671217
# 23  1997           101.270150
# 24  1998           101.451892
# 25  1999           101.878533
# 26  2000           102.137608
# 27  2001           100.839092
# 28  2002           100.611215
# 29  2003           100.167364
# 30  2004           100.813075
# 31  2005           100.647475
# 32  2006           100.857158
# 33  2007           100.716211
# 34  2008            98.031256
# 35  2009            98.294634
# 36  2010            99.309308
# 37  2011            98.692940
# 38  2012            98.843416
# 39  2013            99.380310
# 40  2014            99.933101
# 41  2015           100.545725
# 42  2016           100.432325
# 43  2017           100.874308
# 44  2018           101.075250
# 45  2019           100.738492
# 46  2020            98.812929
# 47  2021            99.819628
# 48  2022            97.306502
# 49  2023            98.218963
# 50  2024            99.038890

# %% [markdown]
# ### Join the tables to make it in one dataframe

# %%
merged_data = unemployment1.merge(stocks_data1, on= 'Date', how = 'left')
merged_data = merged_data.merge(RD_spending_data1, left_on= 'Date', right_on= 'Year', how = 'right')
merged_data = merged_data.merge(productivity_data1, left_on= 'Date', right_on= 'REF_DATE', how = 'right')
merged_data = merged_data.merge(interest_rate, on = 'Date', how= 'left')
merged_data = merged_data.merge(gdp1, on = 'Date', how = 'left')
merged_data = merged_data.merge(cpi1, on = 'Date', how = 'left')
merged_data = merged_data.merge(consumer_confidence1, on = 'Date', how = 'left')
merged_data = merged_data.merge(dependent, left_on = 'Date', right_on = 'Year', how = 'left')
merged_data
# Out:
#     Date  unemployement_rate  stock_value  Year_x  R&D Spending  REF_DATE  \
# 0   1997                9.09      4086.23    1997      1.613860      1997
# 1   1998                8.29      1535.88    1998      1.710510      1998
# 2   1999                7.57      1593.55    1999      1.749850      1999
# 3   2000                6.83      2170.73    2000      1.858480      2000
# 4   2001                7.22      1763.55    2001      2.021170      2001
# 5   2002                7.68      1611.23    2002      1.971710      2002
# 6   2003                7.59      1632.89    2003      1.967810      2003
# 7   2004                7.15      1969.48    2004      1.997340      2004
# 8   2005                6.75      2314.70    2005      1.971270      2005
# 9   2006                6.45      2748.42    2006      1.943040      2006
# 10  2007                6.16      3110.65    2007      1.903580      2007
# 11  2008                6.31      2861.70    2008      1.855780      2008
# 12  2009                8.46      2328.43    2009      1.917420      2009
# 13  2010                8.14      2765.09    2010      1.825280      2010
# 14  2011                7.62      2979.26    2011      1.787140      2011
# 15  2012                7.41      2782.02    2012      1.772320      2012
# 16  2013                7.18      2919.09    2013      1.705400      2013
# 17  2014                7.03      3338.54    2014      1.714170      2014
# 18  2015                6.95      3259.58    2015      1.693240      2015
# 19  2016                7.03      3226.83    2016      1.729030      2016
# 20  2016                7.03      3226.83    2016      1.729030      2016
# 21  2017                6.41      3566.39    2017      1.687020      2017
# 22  2017                6.41      3566.39    2017      1.687020      2017
# 23  2017                6.41      3566.39    2017      1.687020      2017
# 24  2018                5.85      3597.58    2018      1.737200      2018
# 25  2018                5.85      3597.58    2018      1.737200      2018
# 26  2018                5.85      3597.58    2018      1.737200      2018
# 27  2018                5.85      3597.58    2018      1.737200      2018
# 28  2019                5.70      3750.48    2019      1.755730      2019
# 29  2019                5.70      3750.48    2019      1.755730      2019
# 30  2019                5.70      3750.48    2019      1.755730      2019
# 31  2020                9.72      3683.18    2020      1.894840      2020
# 32  2020                9.72      3683.18    2020      1.894840      2020
# 33  2020                9.72      3683.18    2020      1.894840      2020
# 34  2021                7.48      4537.20    2021      1.697270      2021
# 35  2021                7.48      4537.20    2021      1.697270      2021
# 36  2021                7.48      4537.20    2021      1.697270      2021
# 37  2021                7.48      4537.20    2021      1.697270      2021
# 38  2022                5.27      4639.44    2022      1.551820      2022
# 39  2022                5.27      4639.44    2022      1.551820      2022
# 40  2022                5.27      4639.44    2022      1.551820      2022
# 41  2022                5.27      4639.44    2022      1.551820      2022
# 42  2023                5.41      4649.78    2023      1.740393      2023
# 43  2023                5.41      4649.78    2023      1.740393      2023
# 2     1999               Internet   Growing Bubble
# 3     2000               Internet      Full Bubble
# 4     2001               Internet     Bubble Burst
# 5     2002           Social Media  Emerging Bubble
# 6     2003           Social Media  Emerging Bubble
# 7     2004           Social Media   Growing Bubble
# 8     2005           Social Media   Growing Bubble
# 9     2006           Social Media      Full Bubble
# 10    2007           Social Media      Full Bubble
# 11    2008           Social Media   Growing Bubble
# 12    2009           Social Media   Growing Bubble
# 13    2010      Mobile Technology  Emerging Bubble
# 14    2011      Mobile Technology   Growing Bubble
# 15    2012      Mobile Technology      Full Bubble
# 16    2013      Mobile Technology   Growing Bubble
# 17    2014      Mobile Technology   Growing Bubble
# 18    2015             Blockchain  Emerging Bubble
# 19    2016             Blockchain   Growing Bubble
# 20    2016        Virtual Reality  Emerging Bubble
# 21    2017             Blockchain   Growing Bubble
# 22    2017        Virtual Reality   Growing Bubble
# 23    2017      Augmented Reality  Emerging Bubble
# 24    2018             Blockchain      Full Bubble
# 25    2018        Virtual Reality      Full Bubble
# 26    2018      Augmented Reality   Growing Bubble
# 27    2018     Internet of Things  Emerging Bubble
# 28    2019             Blockchain      Full Bubble
# 29    2019      Augmented Reality      Full Bubble
# 30    2019     Internet of Things   Growing Bubble
# 31    2020                     AI  Emerging Bubble
# 32    2020     Internet of Things   Growing Bubble
# 33    2020      Augmented Reality   Growing Bubble
# 34    2021                     AI   Growing Bubble
# 35    2021     Internet of Things      Full Bubble
# 36    2021      Augmented Reality      Full Bubble
# 37    2021          5G Technology  Emerging Bubble
# 38    2022                     AI   Growing Bubble
# 39    2022     Internet of Things   Growing Bubble
# 40    2022      Augmented Reality   Growing Bubble
# 41    2022          5G Technology   Growing Bubble
# 42    2023                     AI      Full Bubble
# 43    2023      Quantum Computing  Emerging Bubble
# 44    2023    Internet of Things       Full Bubble
# 45    2023      Augmented Reality      Full Bubble
# 46    2023          5G Technology   Growing Bubble
# 47    2023  Renewable Energy Tech   Growing Bubble

# %% [markdown]
# ### Drop columns

# %%
final_merged_data = merged_data.drop(['Year_x','REF_DATE','Year_y'],axis=1)
final_merged_data
# Out:
#     Date  unemployement_rate  stock_value  R&D Spending  labour_productivity  \
# 0   1997                9.09      4086.23      1.613860                 50.0
# 1   1998                8.29      1535.88      1.710510                 53.4
# 2   1999                7.57      1593.55      1.749850                 53.5
# 3   2000                6.83      2170.73      1.858480                 53.1
# 4   2001                7.22      1763.55      2.021170                 54.9
# 5   2002                7.68      1611.23      1.971710                 57.4
# 6   2003                7.59      1632.89      1.967810                 57.8
# 7   2004                7.15      1969.48      1.997340                 58.0
# 8   2005                6.75      2314.70      1.971270                 58.1
# 9   2006                6.45      2748.42      1.943040                 61.0
# 10  2007                6.16      3110.65      1.903580                 62.5
# 11  2008                6.31      2861.70      1.855780                 60.6
# 12  2009                8.46      2328.43      1.917420                 62.4
# 13  2010                8.14      2765.09      1.825280                 61.8
# 14  2011                7.62      2979.26      1.787140                 62.7
# 15  2012                7.41      2782.02      1.772320                 63.9
# 16  2013                7.18      2919.09      1.705400                 65.8
# 17  2014                7.03      3338.54      1.714170                 66.6
# 32      0.25  146816.000000  137.0            98.812929
# 33      0.25  146816.000000  137.0            98.812929
# 34      0.25  153897.000000  141.6            99.819628
# 35      0.25  153897.000000  141.6            99.819628
# 36      0.25  153897.000000  141.6            99.819628
# 37      0.25  153897.000000  141.6            99.819628
# 38      4.25  156592.000000  151.2            97.306502
# 39      4.25  156592.000000  151.2            97.306502
# 40      4.25  156592.000000  151.2            97.306502
# 41      4.25  156592.000000  151.2            97.306502
# 42      5.00  157319.500000  157.1            98.218963
# 43      5.00  157319.500000  157.1            98.218963
# 44      5.00  157319.500000  157.1            98.218963
# 45      5.00  157319.500000  157.1            98.218963
# 46      5.00  157319.500000  157.1            98.218963
# 47      5.00  157319.500000  157.1            98.218963
#
#                Technology    Bubble_Status
# 0                Internet      Full Bubble
# 1                Internet   Growing Bubble
# 2                Internet   Growing Bubble
# 3                Internet      Full Bubble
# 4                Internet     Bubble Burst
# 5            Social Media  Emerging Bubble
# 6            Social Media  Emerging Bubble
# 7            Social Media   Growing Bubble
# 8            Social Media   Growing Bubble
# 9            Social Media      Full Bubble
# 10           Social Media      Full Bubble
# 11           Social Media   Growing Bubble
# 12           Social Media   Growing Bubble
# 13      Mobile Technology  Emerging Bubble
# 14      Mobile Technology   Growing Bubble
# 15      Mobile Technology      Full Bubble
# 16      Mobile Technology   Growing Bubble
# 17      Mobile Technology   Growing Bubble
# 18             Blockchain  Emerging Bubble
# 19             Blockchain   Growing Bubble
# 20        Virtual Reality  Emerging Bubble
# 21             Blockchain   Growing Bubble
# 22        Virtual Reality   Growing Bubble
# 23      Augmented Reality  Emerging Bubble
# 24             Blockchain      Full Bubble
# 25        Virtual Reality      Full Bubble
# 26      Augmented Reality   Growing Bubble
# 27     Internet of Things  Emerging Bubble
# 28             Blockchain      Full Bubble
# 29      Augmented Reality      Full Bubble
# 30     Internet of Things   Growing Bubble
# 31                     AI  Emerging Bubble
# 32     Internet of Things   Growing Bubble
# 33      Augmented Reality   Growing Bubble
# 34                     AI   Growing Bubble
# 35     Internet of Things      Full Bubble
# 36      Augmented Reality      Full Bubble
# 37          5G Technology  Emerging Bubble
# 38                     AI   Growing Bubble
# 39     Internet of Things   Growing Bubble
# 40      Augmented Reality   Growing Bubble
# 41          5G Technology   Growing Bubble
# 42                     AI      Full Bubble
# 43      Quantum Computing  Emerging Bubble
# 44    Internet of Things       Full Bubble
# 45      Augmented Reality      Full Bubble
# 46          5G Technology   Growing Bubble
# 47  Renewable Energy Tech   Growing Bubble

# %%
#Check point
final_data = final_merged_data.copy()
final_merged_data.to_csv('Tech Bubbles data.csv')

# %% [markdown]
# ### Encode the data

# %%
#Encoding the Technology
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
final_data['Technology_en'] = le.fit_transform(final_data['Technology'])
final_data
# Out:
#     Date  unemployement_rate  stock_value  R&D Spending  labour_productivity  \
# 0   1997                9.09      4086.23      1.613860                 50.0
# 1   1998                8.29      1535.88      1.710510                 53.4
# 2   1999                7.57      1593.55      1.749850                 53.5
# 3   2000                6.83      2170.73      1.858480                 53.1
# 4   2001                7.22      1763.55      2.021170                 54.9
# 41          5G Technology   Growing Bubble              0
# 42                     AI      Full Bubble              1
# 43      Quantum Computing  Emerging Bubble              8
# 44    Internet of Things       Full Bubble              6
# 45      Augmented Reality      Full Bubble              2
# 46          5G Technology   Growing Bubble              0
# 47  Renewable Energy Tech   Growing Bubble              9

# %%
#Encoding Bubbles 
final_data['Bubble_state'] = le.fit_transform(final_data['Bubble_Status'])
final_data
# Out:
#     Date  unemployement_rate  stock_value  R&D Spending  labour_productivity  \
# 0   1997                9.09      4086.23      1.613860                 50.0
# 1   1998                8.29      1535.88      1.710510                 53.4
# 2   1999                7.57      1593.55      1.749850                 53.5
# 3   2000                6.83      2170.73      1.858480                 53.1
# 4   2001                7.22      1763.55      2.021170                 54.9
# 5   2002                7.68      1611.23      1.971710                 57.4
# 6   2003                7.59      1632.89      1.967810                 57.8
# 7   2004                7.15      1969.48      1.997340                 58.0
# 8   2005                6.75      2314.70      1.971270                 58.1
# 9   2006                6.45      2748.42      1.943040                 61.0
# 10  2007                6.16      3110.65      1.903580                 62.5
# 11  2008                6.31      2861.70      1.855780                 60.6
# 12  2009                8.46      2328.43      1.917420                 62.4
# 13  2010                8.14      2765.09      1.825280                 61.8
# 14  2011                7.62      2979.26      1.787140                 62.7
# 15  2012                7.41      2782.02      1.772320                 63.9
# 16  2013                7.18      2919.09      1.705400                 65.8
# 17  2014                7.03      3338.54      1.714170                 66.6
# 18  2015                6.95      3259.58      1.693240                 70.6
# 19  2016                7.03      3226.83      1.729030                 72.1
# 20  2016                7.03      3226.83      1.729030                 72.1
# 21  2017                6.41      3566.39      1.687020                 79.2
# 22  2017                6.41      3566.39      1.687020                 79.2
# 23  2017                6.41      3566.39      1.687020                 79.2
# 24  2018                5.85      3597.58      1.737200                 81.9
# 25  2018                5.85      3597.58      1.737200                 81.9
# 26  2018                5.85      3597.58      1.737200                 81.9
# 27  2018                5.85      3597.58      1.737200                 81.9
# 28  2019                5.70      3750.48      1.755730                 82.5
# 29  2019                5.70      3750.48      1.755730                 82.5
# 30  2019                5.70      3750.48      1.755730                 82.5
# 31  2020                9.72      3683.18      1.894840                 88.6
# 32  2020                9.72      3683.18      1.894840                 88.6
# 33  2020                9.72      3683.18      1.894840                 88.6
# 34  2021                7.48      4537.20      1.697270                 86.5
# 35  2021                7.48      4537.20      1.697270                 86.5
# 36  2021                7.48      4537.20      1.697270                 86.5
# 37  2021                7.48      4537.20      1.697270                 86.5
# 38  2022                5.27      4639.44      1.551820                 90.8
# 39  2022                5.27      4639.44      1.551820                 90.8
# 40  2022                5.27      4639.44      1.551820                 90.8
# 41  2022                5.27      4639.44      1.551820                 90.8
# 42  2023                5.41      4649.78      1.740393                 87.3
# 43  2023                5.41      4649.78      1.740393                 87.3
# 44  2023                5.41      4649.78      1.740393                 87.3
# 45  2023                5.41      4649.78      1.740393                 87.3
# 46  2023                5.41      4649.78      1.740393                 87.3
# 47  2023                5.41      4649.78      1.740393                 87.3
#
#     Interest            GDP    CPI  consumer_confidence  \
# 0       4.35   68998.083333   90.4           101.270150
# 1       5.05   70986.916667   91.3           101.451892
# 21             Blockchain   Growing Bubble              3             3
# 22        Virtual Reality   Growing Bubble             11             3
# 23      Augmented Reality  Emerging Bubble              2             1
# 24             Blockchain      Full Bubble              3             2
# 25        Virtual Reality      Full Bubble             11             2
# 26      Augmented Reality   Growing Bubble              2             3
# 27     Internet of Things  Emerging Bubble              5             1
# 28             Blockchain      Full Bubble              3             2
# 29      Augmented Reality      Full Bubble              2             2
# 30     Internet of Things   Growing Bubble              5             3
# 31                     AI  Emerging Bubble              1             1
# 32     Internet of Things   Growing Bubble              5             3
# 33      Augmented Reality   Growing Bubble              2             3
# 34                     AI   Growing Bubble              1             3
# 35     Internet of Things      Full Bubble              5             2
# 36      Augmented Reality      Full Bubble              2             2
# 37          5G Technology  Emerging Bubble              0             1
# 38                     AI   Growing Bubble              1             3
# 39     Internet of Things   Growing Bubble              5             3
# 40      Augmented Reality   Growing Bubble              2             3
# 41          5G Technology   Growing Bubble              0             3
# 42                     AI      Full Bubble              1             2
# 43      Quantum Computing  Emerging Bubble              8             1
# 44    Internet of Things       Full Bubble              6             2
# 45      Augmented Reality      Full Bubble              2             2
# 46          5G Technology   Growing Bubble              0             3
# 47  Renewable Energy Tech   Growing Bubble              9             3

# %%
#Remove the columns
final_data.drop(['Technology','Bubble_Status', 'Date'], axis = 1, inplace = True)
final_data
# Out:
#     unemployement_rate  stock_value  R&D Spending  labour_productivity  \
# 0                 9.09      4086.23      1.613860                 50.0
# 1                 8.29      1535.88      1.710510                 53.4
# 2                 7.57      1593.55      1.749850                 53.5
# 3                 6.83      2170.73      1.858480                 53.1
# 4                 7.22      1763.55      2.021170                 54.9
# 5                 7.68      1611.23      1.971710                 57.4
# 6                 7.59      1632.89      1.967810                 57.8
# 7                 7.15      1969.48      1.997340                 58.0
# 8                 6.75      2314.70      1.971270                 58.1
# 9                 6.45      2748.42      1.943040                 61.0
# 10                6.16      3110.65      1.903580                 62.5
# 11                6.31      2861.70      1.855780                 60.6
# 12                8.46      2328.43      1.917420                 62.4
# 13                8.14      2765.09      1.825280                 61.8
# 14                7.62      2979.26      1.787140                 62.7
# 15                7.41      2782.02      1.772320                 63.9
# 16                7.18      2919.09      1.705400                 65.8
# 17                7.03      3338.54      1.714170                 66.6
# 18                6.95      3259.58      1.693240                 70.6
# 19                7.03      3226.83      1.729030                 72.1
# 20                7.03      3226.83      1.729030                 72.1
# 21                6.41      3566.39      1.687020                 79.2
# 22                6.41      3566.39      1.687020                 79.2
# 23                6.41      3566.39      1.687020                 79.2
# 24                5.85      3597.58      1.737200                 81.9
# 25                5.85      3597.58      1.737200                 81.9
# 26                5.85      3597.58      1.737200                 81.9
# 27                5.85      3597.58      1.737200                 81.9
# 28                5.70      3750.48      1.755730                 82.5
# 29                5.70      3750.48      1.755730                 82.5
# 30                5.70      3750.48      1.755730                 82.5
# 31                9.72      3683.18      1.894840                 88.6
# 32                9.72      3683.18      1.894840                 88.6
# 33                9.72      3683.18      1.894840                 88.6
# 34                7.48      4537.20      1.697270                 86.5
# 35                7.48      4537.20      1.697270                 86.5
# 36                7.48      4537.20      1.697270                 86.5
# 37                7.48      4537.20      1.697270                 86.5
# 38                5.27      4639.44      1.551820                 90.8
# 39                5.27      4639.44      1.551820                 90.8
# 40                5.27      4639.44      1.551820                 90.8
# 41                5.27      4639.44      1.551820                 90.8
# 42                5.41      4649.78      1.740393                 87.3
# 43                5.41      4649.78      1.740393                 87.3
# 44                5.41      4649.78      1.740393                 87.3
# 45                5.41      4649.78      1.740393                 87.3
# 46                5.41      4649.78      1.740393                 87.3
# 47                5.41      4649.78      1.740393                 87.3
#
#     Interest            GDP    CPI  consumer_confidence  Technology_en  \
# 0       4.35   68998.083333   90.4           101.270150              4
# 1       5.05   70986.916667   91.3           101.451892              4
# 2       4.75   74535.833333   92.9           101.878533              4
# 3       5.75   78012.333333   95.4           102.137608              4
# 4       2.25   81636.000000   97.8           100.839092              4
# 5       2.75   83339.083333  100.0           100.611215             10
# 6       2.75   84585.750000  102.8           100.167364             10
# 7       2.50   89022.916667  104.7           100.813075             10
# 8       3.00   92295.833333  107.0           100.647475             10
# 9       4.25   99763.666667  109.1           100.857158             10
# 10      4.25  103770.000000  111.5           100.716211             10
# 11      1.50  102256.166667  114.1            98.031256             10
# 12      0.25  101237.083333  114.4            98.294634             10
# 13      1.00  103440.916667  116.5            99.309308              7
# 14      1.00  106951.000000  119.9            98.692940              7
# 15      1.00  108869.000000  121.7            98.843416              7
# 16      1.00  112858.166667  122.8            99.380310              7
# 17      1.00  116034.000000  125.2            99.933101              7
# 18      0.50  121689.083333  126.6           100.545725              3
# 19      0.50  125965.833333  128.4           100.432325              3
# 20      0.50  125965.833333  128.4           100.432325             11
# 21      1.00  134991.000000  130.4           100.874308              3
# 22      1.00  134991.000000  130.4           100.874308             11
# 23      1.00  134991.000000  130.4           100.874308              2
# 24      1.75  138363.000000  133.4           101.075250              3
# 25      1.75  138363.000000  133.4           101.075250             11
# 26      1.75  138363.000000  133.4           101.075250              2
# 27      1.75  138363.000000  133.4           101.075250              5
# 28      1.75  142002.000000  136.0           100.738492              3
# 29      1.75  142002.000000  136.0           100.738492              2
# 30      1.75  142002.000000  136.0           100.738492              5
# 31      0.25  146816.000000  137.0            98.812929              1
# 32      0.25  146816.000000  137.0            98.812929              5
# 33      0.25  146816.000000  137.0            98.812929              2
# 34      0.25  153897.000000  141.6            99.819628              1
# 35      0.25  153897.000000  141.6            99.819628              5
# 36      0.25  153897.000000  141.6            99.819628              2
# 37      0.25  153897.000000  141.6            99.819628              0
# 38      4.25  156592.000000  151.2            97.306502              1
# 39      4.25  156592.000000  151.2            97.306502              5
# 40      4.25  156592.000000  151.2            97.306502              2
# 41      4.25  156592.000000  151.2            97.306502              0
# 42      5.00  157319.500000  157.1            98.218963              1
# 43      5.00  157319.500000  157.1            98.218963              8
# 44      5.00  157319.500000  157.1            98.218963              6
# 45      5.00  157319.500000  157.1            98.218963              2
# 46      5.00  157319.500000  157.1            98.218963              0
# 47      5.00  157319.500000  157.1            98.218963              9
#
#     Bubble_state
# 0              2
# 1              3
# 2              3
# 3              2
# 4              0
# 5              1
# 6              1
# 7              3
# 8              3
# 9              2
# 10             2
# 11             3
# 12             3
# 13             1
# 14             3
# 15             2
# 16             3
# 17             3
# 18             1
# 19             3
# 20             1
# 21             3
# 22             3
# 23             1
# 24             2
# 25             2
# 26             3
# 27             1
# 28             2
# 29             2
# 30             3
# 31             1
# 32             3
# 33             3
# 34             3
# 35             2
# 36             2
# 37             1
# 38             3
# 39             3
# 40             3
# 41             3
# 42             2
# 43             1
# 44             2
# 45             2
# 46             3
# 47             3

# %%
#Check point
data = final_data.copy()

# %% [markdown]
# ## Model Design

# %%
sns.heatmap(data.corr(), annot= True)
# Out:
# <Axes: >

# %%
data['Bubble_state'].value_counts()
# Out:
# Bubble_state
# 3    23
# 2    14
# 1    10
# 0     1
# Name: count, dtype: int64

# %%
#Divide data into dependent and independent variables
X = data.drop(['Bubble_state'], axis= 1)
y = data.iloc[:,-1:]

# %%
from imblearn.over_sampling import RandomOverSampler

oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(X, y)

balanced_data = pd.DataFrame(X_resampled, columns=X.columns)
balanced_data['Bubble_State'] = y_resampled

# %%
balanced_data['Bubble_State'].value_counts()
# Out:
# Bubble_State
# 2    23
# 3    23
# 0    23
# 1    23
# Name: count, dtype: int64

# %%
sns.heatmap(balanced_data.corr(), annot= True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5,5))
sns.pairplot(balanced_data)
plt.show()
# Out:
# /Users/usmanali/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from pandas.plotting import scatter_matrix

# Scatter matrix plot
scatter_matrix(balanced_data, alpha=0.7, figsize=(10, 10), diagonal='kde')
plt.show()

# %%
balanced_data.drop(['Interest', 'unemployement_rate','consumer_confidence'],axis=1,inplace=True)

# %%
X = balanced_data.drop(['Bubble_State'], axis= 1)
y = balanced_data.iloc[:,-1:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.1)

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()
lg.fit(X_train,y_train)
lg.score(X_test,y_test)
# Out:
# /Users/usmanali/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/usmanali/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6

# %%
#Decision Tree
from sklearn import tree
dt_model=tree.DecisionTreeRegressor()
dt_model.fit(X_train,y_train)
dt_score=dt_model.score(X_test,y_test)
print("Decision Tree model score:",dt_score)
# Out:
# Decision Tree model score: 0.3258426966292136

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
random_forest_model=RandomForestRegressor()
random_forest_model.fit(X_train,y_train)
random_forest_score=random_forest_model.score(X_test,y_test)
print("Random Forest Score is:",random_forest_score)
# Out:
# Random Forest Score is: 0.4476516853932586
# /var/folders/b2/pn6h715x3rz171jbp1s72snr0000gn/T/ipykernel_94529/3067203894.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random_forest_model.fit(X_train,y_train)

# %%
#KNN
from sklearn.neighbors import KNeighborsRegressor
knn_model=KNeighborsRegressor()
knn_model.fit(X_train,y_train)
knn_score=knn_model.score(X_test,y_test)
print("KNN score:",knn_score)
# Out:
# KNN score: 0.0022471910112362714

# %%
#Gradient Boost
from sklearn.ensemble import GradientBoostingRegressor
gradient_boost_model=GradientBoostingRegressor(
                                               )
gradient_boost_model.fit(X_train,y_train)
gradient_boost_score=gradient_boost_model.score(X_test,y_test)
print("Gradient Boost Model Score:",gradient_boost_score)
# Out:
# Gradient Boost Model Score: 0.5553753940614887
# /Users/usmanali/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_gb.py:570: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#XGBoost
import xgboost as xgb
xgb_model = xgb.XGBRegressor()
xgb_model.fit(X_train,y_train)
xgb_score=xgb_model.score(X_test,y_test)
print("XG Boost score:",xgb_score)
# Out:
# XG Boost score: 0.4862758694289925

# %%
#AdaBoost
from sklearn.ensemble import AdaBoostRegressor
adaboost_model=AdaBoostRegressor()
adaboost_model.fit(X_train,y_train)
adaboost_score=adaboost_model.score(X_test,y_test)
print('ADA boost model score:',adaboost_score)
# Out:
# ADA boost model score: 0.5471468582084693
# /Users/usmanali/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# #GridSearchCV on XGBoost
# from sklearn.model_selection import GridSearchCV
#
#
# # Define the parameter grid for GridSearchCV
# param_grid = {
#     'n_estimators': [10, 20, 50],           # Number of trees
#     'learning_rate': [0.01, 0.1, 0.2],        # Step size for each update
#     'max_depth': [5, 7, 9, 10, 11],                   # Maximum tree depth
#     'subsample': [0.5, 0.6, 0.8],                  # Fraction of samples to be used per tree
#     'colsample_bytree': [0.8, 1.0, 1.2],           # Fraction of features to be used per tree
#     'gamma': [0.1, 0.3, 0.4, 0.5],                   # Minimum loss reduction required to make a split
#     'reg_alpha': [0.01, 0.1, 0.5],               # L1 regularization term on weights
#     'reg_lambda': [1.5, 2.0, 3.0]               # L2 regularization term on weights
# }
#
# # Set up GridSearchCV with cross-validation
# grid_search = GridSearchCV(
#     estimator=xgb_model,
#     param_grid=param_grid,
#     cv=5,                      # 5-fold cross-validation
#     scoring='r2',              # Use R^2 as the scoring metric for regression
#     verbose=1,                 # Print out progress
#     n_jobs=-1                  # Use all available CPU cores
# )
#
# # Fit the model on the training data
# grid_search.fit(X_train, y_train)
#
# # Display the best parameters and best score
# print("Best parameters found: ", grid_search.best_params_)
# print("Best cross-validation R^2 score: {:.2f}".format(grid_search.best_score_))
#
# # Evaluate the model on the test set with the best parameters
# best_xgb_model = grid_search.best_estimator_
# xgb_score = best_xgb_model.score(X_test, y_test)
# print("XGBoost test set R^2 score:", xgb_score)

# %%
balanced_data
# Out:
#     stock_value  R&D Spending  labour_productivity            GDP    CPI  \
# 0       4086.23      1.613860                 50.0   68998.083333   90.4
# 1       1535.88      1.710510                 53.4   70986.916667   91.3
# 2       1593.55      1.749850                 53.5   74535.833333   92.9
# 3       2170.73      1.858480                 53.1   78012.333333   95.4
# 4       1763.55      2.021170                 54.9   81636.000000   97.8
# ..          ...           ...                  ...            ...    ...
# 87      3750.48      1.755730                 82.5  142002.000000  136.0
# 88      4649.78      1.740393                 87.3  157319.500000  157.1
# 89      4649.78      1.740393                 87.3  157319.500000  157.1
# 90      3597.58      1.737200                 81.9  138363.000000  133.4
# 91      2170.73      1.858480                 53.1   78012.333333   95.4
#
#     Technology_en  Bubble_State
# 0               4             2
# 1               4             3
# 2               4             3
# 3               4             2
# 4               4             0
# ..            ...           ...
# 87              3             2
# 88              1             2
# 89              2             2
# 90              3             2
# 91              4             2
#
# [92 rows x 7 columns]

# %%
y
# Out:
#     Bubble_State
# 0              2
# 1              3
# 2              3
# 3              2
# 4              0
# ..           ...
# 87             2
# 88             2
# 89             2
# 90             2
# 91             2
#
# [92 rows x 1 columns]
